# %%
# !pip install open_clip_torch transformers
# Out:
# Requirement already satisfied: open_clip_torch in /opt/anaconda3/lib/python3.9/site-packages (2.20.0)
# Collecting transformers
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      |████████████████████████████████| 7.2 MB 4.3 MB/s eta 0:00:01
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.9/site-packages (from open_clip_torch) (4.62.3)
# Requirement already satisfied: ftfy in /opt/anaconda3/lib/python3.9/site-packages (from open_clip_torch) (6.1.1)
# Requirement already satisfied: timm in /opt/anaconda3/lib/python3.9/site-packages (from open_clip_torch) (0.9.2)
# Requirement already satisfied: torchvision in /opt/anaconda3/lib/python3.9/site-packages (from open_clip_torch) (0.15.1)
# Requirement already satisfied: protobuf<4 in /opt/anaconda3/lib/python3.9/site-packages (from open_clip_torch) (3.20.3)
# Requirement already satisfied: sentencepiece in /opt/anaconda3/lib/python3.9/site-packages (from open_clip_torch) (0.1.99)
# Requirement already satisfied: torch>=1.9.0 in /opt/anaconda3/lib/python3.9/site-packages (from open_clip_torch) (2.0.0)
# Requirement already satisfied: huggingface-hub in /opt/anaconda3/lib/python3.9/site-packages (from open_clip_torch) (0.15.1)
# Requirement already satisfied: regex in /opt/anaconda3/lib/python3.9/site-packages (from open_clip_torch) (2021.8.3)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.9/site-packages (from transformers) (3.3.1)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/anaconda3/lib/python3.9/site-packages (from transformers) (0.3.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-macosx_10_11_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 23.4 MB/s eta 0:00:01
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.9/site-packages (from transformers) (2.26.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.9/site-packages (from transformers) (21.0)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/lib/python3.9/site-packages (from transformers) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.9/site-packages (from transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub->open_clip_torch) (3.10.0.2)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub->open_clip_torch) (2021.8.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->transformers) (3.0.4)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.9/site-packages (from torch>=1.9.0->open_clip_torch) (2.6.3)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.9/site-packages (from torch>=1.9.0->open_clip_torch) (1.9)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.9/site-packages (from torch>=1.9.0->open_clip_torch) (2.11.3)
# Requirement already satisfied: wcwidth>=0.2.5 in /opt/anaconda3/lib/python3.9/site-packages (from ftfy->open_clip_torch) (0.2.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.9/site-packages (from jinja2->torch>=1.9.0->open_clip_torch) (1.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests->transformers) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests->transformers) (1.26.7)
# Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/lib/python3.9/site-packages (from sympy->torch>=1.9.0->open_clip_torch) (1.2.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from torchvision->open_clip_torch) (8.4.0)
# Installing collected packages: tokenizers, transformers
# Successfully installed tokenizers-0.13.3 transformers-4.30.2

# %%
import open_clip
import torch

model, _, transform = open_clip.create_model_and_transforms(
  model_name="coca_ViT-L-14",
  pretrained="mscoco_finetuned_laion2B-s13B-b90k"
)
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# Downloading (…)ip_pytorch_model.bin: 100%|██████████| 2.55G/2.55G [01:46<00:00, 24.0MB/s]

# %%
# !wget https://i.imgur.com/8H7XCH0.jpg -O cat.jpg
# Out:
# zsh:1: command not found: wget

# %%
from IPython.display import Image
image_name = "food3.jpeg"
Image(image_name)

# %%
from PIL import Image
im = Image.open(image_name).convert("RGB")
im = transform(im).unsqueeze(0)

#with torch.no_grad(), torch.cuda.amp.autocast():
with torch.no_grad():
  generated = model.generate(im)

print(open_clip.decode(generated[0]).split("<end_of_text>")[0].replace("<start_of_text>", ""))
# Out:
# a table topped with bowls of food and chopsticks .
